# %% [markdown]
# <a href="https://colab.research.google.com/github/tahreem636/house_price_regression_dataset/blob/main/house_price_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle competitions download -c house-prices-advanced-regression-techniques
# Out:
# ...
# 403 - Forbidden - You must accept this competition's rules before you'll be able to download files.

# %%
import pandas as pd
df = pd.read_csv('/content/house_price_regression_dataset.csv')
df
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# ...

# %%
# !kaggle datasets download -d prokshitha/home-value-insights
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/prokshitha/home-value-insights
# License(s): other
# ...
#   0% 0.00/26.4k [00:00<?, ?B/s]
# 100% 26.4k/26.4k [00:00<00:00, 23.7MB/s]

# %%
# !unzip \*.zip && rm *.zip
# Out:
# Archive:  home-value-insights.zip
# replace house_price_regression_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
df1=pd.read_csv('house_price_regression_dataset.csv')
df1.head()
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1360             2              1        1981  0.599637
# 1            4272             3              3        2016  4.753014
# 2            3592             1              2        2016  3.634823
# 3             966             1              2        1977  2.730667
# 4            4926             2              1        1993  4.699073
#
#    Garage_Size  Neighborhood_Quality   House_Price
# 0            0                     5  2.623829e+05
# 1            1                     6  9.852609e+05
# 2            0                     9  7.779774e+05
# 3            1                     8  2.296989e+05
# 4            0                     8  1.041741e+06

# %%
#install kaggl
# !pip install -q kaggle
